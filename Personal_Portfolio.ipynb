# %% [markdown]
# <a href="https://colab.research.google.com/github/mintchoco5555/For_Network_Portfolio/blob/main/Personal_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Personal Project**
# ### Name: รสริน เมืองหงษ์
# ### Student ID: 673380289-4
# ### Section: 2

# %% [markdown]
# *Cisco Academy*
#
# ![Screenshot 2026-03-27 213833.png](data:image/png;base64,...)
#
#
# ---
#
#
#
# ![Screenshot 2026-04-01 191823.png](data:image/png;base64,...)

# %% [markdown]
# # *All Assignment*
#
#
# ---

# %% [markdown]
# ## **Assignment 1**
#
# Personal essay : [click here](https://docs.google.com/document/d/1szvcsoSs5IjJO14nkpwMncyqvL1GJ_K5wF_1ofBbsO8/edit?usp=sharing)
#
# Summarize 📖
#
# เครือข่ายคอมพิวเตอร์มีบทบาทสำคัญในชีวิตประจำวัน เพราะช่วยให้การสื่อสารและการใช้งานอินเทอร์เน็ตสะดวกขึ้น ไม่ว่าจะเป็นการตรวจสอบอีเมล อ่านข่าว หรือใช้โซเชียลมีเดีย เช่น Facebook, Instagram และ LINE
#
# ภายในบ้าน อินเทอร์เน็ตผ่านเราเตอร์ช่วยให้สามารถเรียนออนไลน์ ทำงาน และติดต่อกับผู้อื่นได้อย่างต่อเนื่อง หากเกิดปัญหาเบื้องต้นสามารถแก้ไขได้ด้วยการรีสตาร์ทเราเตอร์ ตรวจสอบสายสัญญาณ หรือเช็กการตั้งค่าเครือข่าย
#
# นอกจากนี้ การเดินทางยังพึ่งพา Google Maps ในการดูเส้นทางแบบเรียลไทม์ ซึ่งต้องอาศัยเครือข่ายที่มีความเสถียร
#
# ---
#
#
# ## **Assignment 2**
#
# Topology : [click here](https://docs.google.com/document/d/1M0miDFANb5MxOwFrDO_cvslDjjPaPWnJmTIoXKPX7m8/edit?usp=sharing)
#
# Summarize 📖
#
# #### 1. เครือข่ายที่เล็กที่สุด (Smallest Network)
# เครือข่ายที่เล็กที่สุดคือ เครือข่ายแบบจุดต่อจุด (Point-to-Point) ที่ประกอบด้วยคอมพิวเตอร์เพียงสองเครื่องเชื่อมต่อกันโดยตรงด้วยสายเคเบิล โดยไม่ผ่านอุปกรณ์สวิตช์หรือเราเตอร์ เช่น PC0 และ PC1 ซึ่งมีเพียง 2 โฮสต์ที่เชื่อมต่อกันโดยตรงในเครือข่ายเดียวกัน
#
# #### 2. เครือข่ายที่ต้องใช้สวิตช์ (Network that requires switches)
# เครือข่ายที่ต้องใช้สวิตช์คือเครือข่ายที่มีคอมพิวเตอร์หลายเครื่องอยู่ในเครือข่ายเดียวกัน (LAN เดียวกัน) และต้องการให้อุปกรณ์ทั้งหมดสามารถสื่อสารกันผ่านตัวกลางร่วมกัน โดยสวิตช์ทำหน้าที่เชื่อมต่อและส่งต่อข้อมูลภายใน LAN จากตัวอย่างจะเห็นว่า PC2, PC3 และ PC4 ถูกเชื่อมเข้ากับ Switch0 ซึ่งกระจายข้อมูลให้ทุกอุปกรณ์ที่อยู่ใน LAN เดียวกัน
#
# #### 3. เครือข่ายที่ต้องใช้เราเตอร์ (Network that requires routers)
# เครือข่ายที่ต้องใช้เราเตอร์คือเครือข่ายที่ต้องเชื่อมต่อหลายเครือข่ายเข้าด้วยกัน เช่น หลาย LAN หรือหลาย Subnet เพราะเราเตอร์ทำหน้าที่เลือกเส้นทางและส่งข้อมูลจากเครือข่ายหนึ่งไปยังอีกเครือข่ายหนึ่ง ในตัวอย่างจะเห็นว่าแต่ละสวิตช์มีกลุ่มโฮสต์ของตนเอง ซึ่งถือเป็นเครือข่ายย่อยคนละเครือข่าย และ Router1 ทำหน้าที่เป็นตัวกลางเชื่อม LAN/Subnet เหล่านี้เข้าด้วยกัน ทำให้สามารถสื่อสารข้ามเครือข่ายได้อย่างถูกต้อง
#
# ---
#
# ## **Assignment 3**
#
# Not_simple : [click here](https://docs.google.com/document/d/1cpZWledyVlcafDOawmh-u8OlxJM-Nn5xr9x4TUAEtYY/edit?usp=sharing)
#
#
# ผลการทดลอง
# #### การทดสอบในเครือข่ายเดียวกัน
# - **PC01 ping 192.168.1.3**
#   ผลลัพธ์: Reply from 192.168.1.3: bytes=32 time<1ms TTL=128
#   สรุป: การเชื่อมต่อสำเร็จ มีค่าเวลาในการตอบกลับน้อยกว่า 1 มิลลิวินาที แสดงว่าอุปกรณ์อยู่ในเครือข่ายเดียวกันและมีการเชื่อมต่อที่ดี
#
# - **PC01 ping 192.168.1.4**
#   ผลลัพธ์: Reply from 192.168.1.4: bytes=32 time<1ms TTL=128
#   สรุป: การเชื่อมต่อสำเร็จ มีค่าเวลาในการตอบกลับน้อยกว่า 1 มิลลิวินาที
#
# #### การทดสอบระหว่างเครือข่าย
# - **PC11 ping 192.168.0.2**
#   ผลลัพธ์: Reply from 192.168.0.2: bytes=32 time=9ms TTL=128
#   สรุป: การเชื่อมต่อสำเร็จ แต่มีค่าเวลาในการตอบกลับสูงขึ้น (สูงสุด 9 มิลลิวินาที) เนื่องจากต้องผ่านเราเตอร์เพื่อเชื่อมต่อระหว่างเครือข่าย
#
# - **PC11 ping 192.168.0.3**
#   ผลลัพธ์: Reply from 192.168.0.3: bytes=32 time<1ms TTL=128
#   สรุป: การเชื่อมต่อสำเร็จ แสดงว่าอุปกรณ์ทั้งสองอยู่ในเครือข่ายเดียวกันหรือมีการเชื่อมต่อที่มีประสิทธิภาพดี
#
# ### สรุปผลการทดลอง
# - คำสั่ง Ping เป็นเครื่องมือที่ใช้ทดสอบการเชื่อมต่อระหว่างอุปกรณ์ในเครือข่าย
# - ค่าเวลา (Time) ที่น้อยแสดงถึงการเชื่อมต่อที่ดีและอุปกรณ์อยู่ในเครือข่ายเดียวกัน
# - ค่าเวลา (Time) ที่สูงขึ้นแสดงว่าการเชื่อมต่อต้องผ่านอุปกรณ์ระหว่างทาง เช่น เราเตอร์
# - ค่า TTL (Time to Live) ใช้บอกจำนวนฮ็อปที่ข้อมูลสามารถผ่านได้ก่อนที่จะหมดอายุ
#
# ---
#
# ## **Assignment 4**
#
# TCP-UDP : [click here](https://docs.google.com/document/d/13ARZ8ynKXY0v1sxJhSO_2q5mzC3h6hmWFhFum0JALtA/edit?usp=sharing)
#
# ### ผลการทดลองและข้อสังเกต
#
# | โปรโตคอล | สีที่ปรากฏ | ความหมาย |
# |----------|-----------|---------|
# | HTTP | สีเขียว | การรับส่งข้อมูลเว็บไซต์ |
# | FTP | สีส้ม | การรับส่งไฟล์ |
# | DNS | สีน้ำเงิน | การแปลงชื่อโดเมนเป็น IP |
# | E-Mail | สีม่วง | การส่งอีเมล |
#
# ### คำถามท้ายการทดลอง
#
# **1. การที่ PDU หลายชุดเคลื่อนที่บนเครือข่ายพร้อมกันโดยใช้สื่อกลางเดียวกันเรียกว่าอะไร?**
#
# **คำตอบ:** Multiplexing (การมัลติเพล็กซ์)
#
# **2. สีของ PDU ใน Simulation Panel มีความหมายอย่างไร?**
#
# **คำตอบ:** สีของ PDU ใช้บ่งบอกประเภทของโปรโตคอลที่ใช้ในการสื่อสาร ทำให้สามารถแยกแยะและติดตามการทำงานของแต่ละโปรโตคอลได้ง่ายขึ้น เช่น HTTP, FTP, DNS, SMTP เป็นต้น
#
# ### สรุปผลการทดลอง
# - การจำลองการรับส่งข้อมูลช่วยให้เข้าใจการทำงานของโปรโตคอลต่างๆ ได้ชัดเจนขึ้น
# - Multiplexing เป็นเทคนิคที่ทำให้สามารถส่งข้อมูลหลายชุดพร้อมกันผ่านสื่อกลางเดียวกันได้
# - การใช้สีในการแสดง PDU ช่วยให้แยกประเภทการรับส่งข้อมูลได้ง่าย
# - การทำงานของเครือข่ายต้องอาศัยโปรโตคอลหลายชนิดทำงานร่วมกันเพื่อให้บริการต่างๆ แก่ผู้ใช้

# %% [markdown]
# # *All Lab*
# ---

# %% [markdown]
# ## **Lab1**
# Lab1 : [Click here](https://docs.google.com/document/d/11k4OGAFt3NUgt-DRzoUeIaqRtW3ZguY-RExw4nCjCNQ/edit?usp=sharing)
#
# **บทบาท:** รับผิดชอบ Part 2
#
# **รายละเอียดที่ทำ:**
# - มีส่วนร่วมในการกำหนดค่าอุปกรณ์เครือข่ายเบื้องต้นตาม Addressing Table ที่กำหนด
# - ตรวจสอบการเชื่อมต่อและการห่อหุ้มข้อมูล (Encapsulation) ในเลเยอร์ต่างๆ
# - วิเคราะห์โครงสร้างของ Protocol Headers โดยใช้โหมดจำลอง (Simulation Mode)
# - แก้ไขปัญหาการเชื่อมต่อแบบ Layered Connectivity
# - จัดทำเอกสารการทำงานร่วมกันของ Protocol ต่างๆ
# - ตรวจสอบการทำงานของ ARP (Address Resolution Protocol)
# - วิเคราะห์ ICMP Echo Request/Reply
# - ศึกษา Encapsulation Chain ตั้งแต่ Data ไปจนถึง Bits
#
#
# ---
# ## **Lab2**
# Lab2 : [Click here](https://docs.google.com/document/d/1dMqiBN2k61Y1nLfXnihVHNPONVrl6i2MZSwS6z4F4qY/edit?usp=sharing)
#
# **บทบาท:** รับผิดชอบ Part 5
#
# **รายละเอียดที่ทำ:**
# - ทดสอบการส่ง Ping ด้วยขนาดแพ็กเก็ตต่างๆ เพื่อศึกษา MTU และการแบ่งส่วนข้อมูล (Fragmentation)
# - ล้าง ARP Cache ด้วยคำสั่ง `arp -d` และสังเกตกระบวนการทำงานของ ARP ใหม่
# - ตรวจสอบ MAC Address Table บนสวิตช์ทั้งก่อนและหลังการส่งข้อมูล
# - จัดทำเอกสารอธิบายขั้นตอนการทำงานเมื่อผู้ใช้สั่ง Ping
# - สรุปกระบวนการตั้งแต่การสร้าง ICMP Echo Request, การห่อหุ้มใน IP Packet, การสร้าง Ethernet Frame ด้วย MAC Address จาก ARP, จนถึงการส่งข้อมูลผ่านสื่อกายภาพ
# - ทดสอบ Extended Ping (ปรับเปลี่ยนคำสั่งให้เหมาะสม)
# - ล้าง MAC Address Table แบบ Dynamic และสังเกตการเรียนรู้ MAC Address ใหม่
# - บันทึกและวิเคราะห์ ARP Table ก่อนและหลังการ Ping
#
# ---
#
# ## **Lab3**
# Lab3 : [Click here](https://docs.google.com/document/d/14zPgMoRsEfh0FR6wB3qCvlQg8B4roqL_ugb6Qw2CDko/edit?usp=sharing)
#
# **บทบาท:** รับผิดชอบส่วน Router 2
#
# **รายละเอียดที่ทำ:**
# - กำหนดค่า Subinterface สำหรับ VLAN ต่างๆ บน Router 2
# - ตั้งค่า encapsulation dot1Q สำหรับ VLAN 10, 20 และ 99
# - กำหนด IP Address ให้กับแต่ละ Subinterface (Gateway ของแต่ละ VLAN)
# - เปิดใช้งาน Interface และตรวจสอบสถานะ
# - ตรวจสอบ Routing Table บน Router 2
# - ตรวจสอบสถานะ Interface ด้วย `show ip interface brief`
# - ทดสอบการเชื่อมต่อระหว่าง VLAN
# - ศึกษาและอธิบายความแตกต่างระหว่างการทำงานของ TCP และ MIME
# - วิเคราะห์บทบาทของ ARP ก่อนการสื่อสาร TCP
# - อธิบายตำแหน่งที่เกิด Routing Decision (Layer 3)
# - สรุปหลักการที่ทำให้ความหมายของข้อมูลคงอยู่แม้ผ่านการ Encapsulation หลายชั้น
#
# ---
#
# ## **Lab4**
# Lab4 : [Click here](https://docs.google.com/document/d/1NJnRJEsZ7ckoM6w7Vkn80CA0OOFWpjfKEOCZHGylDng/edit?usp=sharing)
#
# **บทบาทที่ระบุ:** QA/Test
# **บทบาทที่ปฏิบัติจริง:** รับผิดชอบส่วน Router 2 Configuration
#
# **รายละเอียดที่ทำ:**
# - กำหนดค่า Router 2 (R2) ฝั่ง LAN B
# - กำหนดค่า Interface G0/0/0 เชื่อมต่อกับ Simulated Internet (10.10.12.2/30) และตั้งค่าเป็น `ip nat outside`
# - กำหนดค่า Interface G0/0/1 สำหรับ LAN B (192.168.20.1/24) และตั้งค่าเป็น `ip nat inside`
# - ตั้งค่า Static Route ไปยังเครือข่าย LAN A (192.168.10.0/24) ผ่าน Next Hop 10.10.12.1
# - กำหนด Access List และ NAT Overload เพื่อให้ LAN B สามารถเข้าถึงเครือข่ายอื่นผ่าน NAT
# - ตรวจสอบการทำงานด้วย `show ip route`, `show ip nat translations`, และ `ping`
# - ทดสอบการเชื่อมต่อระหว่าง LAN A และ LAN B ผ่าน Simulated Internet
# - ทดสอบ Stateful และ Stateless Services ผ่านโครงสร้างเครือข่ายที่กำหนดค่า
#
# ---
#
# ## **Lab5**
# Lab5 : [Click here](https://docs.google.com/document/d/1vEmWyvEqgFgjgXXdpTUDHExy72YxGuNvlBE9xigtt2s/edit?usp=sharing)
#
# **บทบาท:** รับผิดชอบส่วน Router 2
#
# **รายละเอียดที่ทำ:**
# - กำหนดค่า Hostname เป็น R2
# - กำหนดค่า Interface G0/0/1 สำหรับ LAN B (192.168.20.1/24) พร้อมเปิดใช้งาน
# - กำหนดค่า Interface Serial S0/1/1 สำหรับเชื่อมต่อกับ ISP (100.10.10.2/30)
# - ตั้งค่า Static Route ไปยัง LAN A (192.168.10.0/24) ผ่าน ISP (Next Hop 100.10.10.1)
# - ตั้งค่า Default Route ไปยัง ISP (0.0.0.0 0.0.0.0 100.10.10.1)
# - บันทึกการตั้งค่าด้วย `write memory`
# - ตรวจสอบ Routing Table บน R2
# - ทดสอบการเชื่อมต่อไปยัง R1 ด้วย `ping 100.10.10.1` และตรวจสอบสถิติการตอบกลับ
# - ตรวจสอบสถานะ Interface ทั้งหมด
# - ตรวจสอบว่า ServerB (192.168.20.10) สามารถรับการเชื่อมต่อจากฝั่ง LAN A ได้
# - ทดสอบการทำงานของ Microservices ที่ถูกนำไปใช้บน ServerB
# - ตรวจสอบการทำงานของระบบแบบ Distributed Architecture

# %% [markdown]
# # *Project*
#
#
#
# ---

# %% [markdown]
# ## **New Networking**
# Link : [Click here](https://docs.google.com/document/d/10GTCn2C3_dVl86nlCMyPH1Loigb-Wp-rKgcEauF4hz4/edit?usp=sharing)
#
# แนวคิดที่เสนอ
# AquaLink Network - ระบบเครือข่ายสื่อสารใต้น้ำ เชื่อมต่อระหว่างมนุษย์กับสิ่งมีชีวิตใต้ทะเล ใช้เซ็นเซอร์และคลื่นเสียงในการส่งข้อมูลไปยังสถานีควบคุมบนผิวน้ำ
#
# การมีส่วนร่วมในโครงการ
# 1. การระดมสมองและพัฒนาแนวคิด
#
# เสนอแนวคิด AquaLink Network ซึ่งเป็นระบบเครือข่ายที่สามารถสื่อสารใต้น้ำได้
#
# ร่วมแลกเปลี่ยนความคิดเห็นกับสมาชิกในกลุ่มเกี่ยวกับความเป็นไปได้ของเครือข่ายการสื่อสารระดับจักรวาล
#
# มีส่วนในการวิเคราะห์และสังเคราะห์แนวคิดของสมาชิกแต่ละคน เพื่อนำมาหลอมรวมเป็นแนวคิดหลักของกลุ่ม
#
# 2. การพัฒนาเอกสารโครงการ
#
# ร่วมกันกำหนดทฤษฎีหลักของโครงการ Spacetime Networking
#
# ร่วมจัดทำรายละเอียดเกี่ยวกับเทคโนโลยีและทฤษฎีที่ใช้
#
# ร่วมวิเคราะห์ข้อจำกัดของโครงการ ทั้งด้านฟิสิกส์ เทคโนโลยี ความซับซ้อนของระบบ ความปลอดภัย ต้นทุน และการยอมรับ
#
# ร่วมจัดทำแผนพัฒนาเทคโนโลยีในอนาคต (Roadmap) ตั้งแต่ปัจจุบันถึง ค.ศ. 2077
#
# 3. การเขียนตัวอย่างการใช้งาน (Use Cases)
#
# ร่วมกำหนดตัวอย่างการใช้งานของระบบ Spacetime Networking
#
# รับผิดชอบในการอธิบายรายละเอียดของการสื่อสารระหว่างอาณานิคมนอกโลก (Off-World Colony Communication)
#
# ---

# %% [markdown]
# ## **Final Project**
# ชื่อโปรเจค **Spacetime Networking — Spacecraft-to-Satellite Communication Network (TS-Com)**
#
# Link (Doc) : [Click here](https://docs.google.com/document/d/1ix_ScvImv-sUYtwY_9RzvoHcAfiZ-ymXxHkhE19m4sg/edit?usp=sharing)
# Link(Github, Video, NotebookLM) : [Click here](https://drive.google.com/drive/folders/1pMTUDmsCbXrMSmXztLz72NXbjaL6pmo5?usp=sharing)
#
# รับบทบาทเป็น Engineer มีหน้าที่ในการพัฒนาโปรโตคอลและเขียนโค้ดระบบจำลองทั้งหมด โดยได้พัฒนาระบบครบทุกส่วนตั้งแต่ยานอวกาศ ดาวเทียม ไปจนถึงสถานีภาคพื้นดิน
#
# - เขียนโมดูล sensor.py เพื่อจำลองการทำงานของยานอวกาศที่ส่งข้อมูล Telemetry ผ่าน UDP พร้อมสถานะต่างๆ เช่น สถานะปกติ เตือนภัย หรือฉุกเฉิน
# - พัฒนา client.py สำหรับดาวเทียม(relay) ซึ่งมีกลไกสำคัญคือ Mission QoS ที่จัดลำดับความสำคัญของข้อมูลตามภารกิจ โดยข้อมูลฉุกเฉิน(P0) จะถูกส่งก่อนข้อมูลทั่วไป(P2) เสมอ พร้อมทั้งจำลอง Contact Window ที่เปิดและปิดตามรอบเวลา และใช้ Priority Queue ในการจัดการข้อมูลแบบ Store-and-Forward
# - พัฒนา server.py สำหรับสถานีภาคพื้นดินที่รับข้อมูลจากดาวเทียมผ่าน TCP วัดค่า End-to-End Latency และประมวลผลข้อมูลผ่านระบบหลายเธรด
#
# ผลงานที่ได้คือระบบจำลองการสื่อสารยานอวกาศ-ดาวเทียมที่สามารถทนต่อความหน่วงสูงและสัญญาณขาดช่วงได้อย่างมีประสิทธิภาพ
#
# สิ่งที่ได้เรียนรู้
# - DTN(Delay/Disruption-Tolerant Networking): การสื่อสารแบบ Store-and-Forward ที่ทนต่อความหน่วงสูงและสัญญาณขาดช่วง
#
# - Mission QoS: การจัดลำดับความสำคัญของข้อมูลตามผลกระทบต่อภารกิจ ไม่ใช่ตามขนาดไฟล์
#
# - Contact Window: การจำลองช่วงเวลาที่ลิงก์สื่อสารเปิด/ปิด และการส่งข้อมูลให้สอดคล้องกับช่วงเวลานั้น
#
# - Priority Queue & Preemption : การจัดการคิวที่ข้อมูลฉุกเฉินสามารถแทรกและส่งก่อนข้อมูลทั่วไปได้ทันที
#
# - End-to-End Latency Measurement: การวัดเวลาตั้งแต่ข้อมูลถูกสร้างจนถึงปลายทาง
